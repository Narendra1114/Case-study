# %%
import pandas as pd
df = pd.read_excel (r'C:\Users\Narendra Raushan\Downloads\EDA_census.xlsx')
print(df)
# Out:
#      Unnamed: 0 Unnamed: 1 Unnamed: 2                         Unnamed: 3  \
# 0         Table      State     Distt.                          Area Name
# 1          Name       Code       Code                                NaN
# 2           NaN        NaN        NaN                                NaN
# 3           NaN        NaN        NaN                                NaN
# 4           NaN        NaN        NaN                                NaN
# 5           NaN        NaN        NaN                                NaN
# 6         C2308         00        000                              INDIA
# 7         C2308         00        000                              INDIA
# 8         C2308         00        000                              INDIA
# 9         C2308         00        000                              INDIA
# 10        C2308         00        000                              INDIA
# 11        C2308         00        000                              INDIA
# ...

# %%
from pandas import ExcelFile

df=pd.read_excel("EDA_census.xlsx")
print(df)
# Out:
#      Unnamed: 0 Unnamed: 1 Unnamed: 2                         Unnamed: 3  \
# 0         Table      State     Distt.                          Area Name
# 1          Name       Code       Code                                NaN
# 2           NaN        NaN        NaN                                NaN
# 3           NaN        NaN        NaN                                NaN
# 4           NaN        NaN        NaN                                NaN
# 5           NaN        NaN        NaN                                NaN
# 6         C2308         00        000                              INDIA
# 7         C2308         00        000                              INDIA
# 8         C2308         00        000                              INDIA
# 9         C2308         00        000                              INDIA
# 10        C2308         00        000                              INDIA
# 11        C2308         00        000                              INDIA
# ...
